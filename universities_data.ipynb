# %%
import numpy as np
import pandas as pd

# %%
url = 'https://s3-us-west-2.amazonaws.com/learn-assets.galvanize.com/gSchool/ds-curriculum/sql-block/universities.csv'
universities = pd.read_csv(url, sep = '\t', delimiter=",")

# %%
universities
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
universities.head()
# Out:
#                                       name  \
# 0  A T Still University of Health Sciences
# 1             Abilene Christian University
# 2     Abraham Baldwin Agricultural College
# 3                          Academy College
# 4     Academy for Five Element Acupuncture
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# 3  1101 E. 78th Street, Suite 100, Minneapolis, M...  www.academycollege.edu
# 4         305 SE 2nd Ave, Gainesville, Florida 32601   www.acupuncturist.edu
#
#                                                 Type    Size
# 0                     4-year, Private not-for-profit  3480.0
# 1                     4-year, Private not-for-profit  4669.0
# ...

# %%
universities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Website  2822 non-null   object
#  3   Type     2907 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 113.7+ KB

# %%
universities.describe()
# Out:
#                Size
# count    2829.00000
# mean     4374.88123
# std      9256.38326
# min         4.00000
# 25%       493.00000
# 50%      1478.00000
# 75%      4064.00000
# max    301323.00000

# %%
universities['Type'].unique()
# Out:
# array(['4-year, Private not-for-profit',
#        "4-year, primarily associate's, Public",
#        "4-year, primarily associate's, Private for-profit",
#        '4-year, Private for-profit', '4-year, Public',
#        "4-year, primarily associate's, Private not-for-profit"],
#       dtype=object)

# %%
# universities[‘Type’].unique()
# universities.Type.unique()
universities['Type'].unique().tolist()
# Out:
# ['4-year, Private not-for-profit',
#  "4-year, primarily associate's, Public",
#  "4-year, primarily associate's, Private for-profit",
#  '4-year, Private for-profit',
#  '4-year, Public',
#  "4-year, primarily associate's, Private not-for-profit"]

# %%
universities['Size'].mean()
# Out:
# 4374.881230116649

# %%
universities['Size'].median()
# Out:
# 1478.0

# %%
len(universities['Type'].unique().tolist())
# Out:
# 6

# %%
universities.groupby(['Type'])['Size'].mean().sort_values()
# Out:
# Type
# 4-year, primarily associate's, Private for-profit          934.380597
# 4-year, primarily associate's, Private not-for-profit     1129.413793
# 4-year, Private not-for-profit                            2399.885696
# 4-year, Private for-profit                                3504.501859
# 4-year, primarily associate's, Public                     6889.366197
# 4-year, Public                                           11478.913765
# Name: Size, dtype: float64

# %%
universities.groupby(['Type'])['Size'].median().sort_values()
# Out:
# Type
# 4-year, primarily associate's, Private for-profit         564.5
# 4-year, Private for-profit                                730.0
# 4-year, primarily associate's, Private not-for-profit     768.0
# 4-year, Private not-for-profit                           1206.0
# 4-year, primarily associate's, Public                    3558.0
# 4-year, Public                                           7669.0
# Name: Size, dtype: float64

# %%
address1 = universities['address']
type(address1), address1
address1 = address1.str.strip()
address1
address1 = address1.str.split(',', expand=True).fillna #expand puts results into two separate columns
address1
# Out:
# <bound method DataFrame.fillna of                                   0             1                         2  \
# 0                   800 W Jefferson    Kirksville            Missouri 63501
# 1                 1600 Campus Court       Abilene               Texas 79699
# 2                    2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3               1101 E. 78th Street     Suite 100               Minneapolis
# 4                    305 SE 2nd Ave   Gainesville             Florida 32601
# ...                             ...           ...                       ...
# 2902  13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                  1125 E 8th St          York       Nebraska 68467-2699
# 2904                Country Club Rd          York   Pennsylvania 17403-3651
# 2905           One University Plaza    Youngstown           Ohio 44555-0001
# 2906          320 South Main Street     Haverhill       Massachusetts 01835
#
# ...

# %%
address1 = universities['address']
address1 = address1.str.strip()
address1 = address1.str.split(',', expand=True) #expand puts results into two separate columns
address2 = address1.rename(columns={0:'street', 1:'city', 2:'state zipcode'})
address2
# Out:
#                              street          city             state zipcode  \
# 0                   800 W Jefferson    Kirksville            Missouri 63501
# 1                 1600 Campus Court       Abilene               Texas 79699
# 2                    2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3               1101 E. 78th Street     Suite 100               Minneapolis
# 4                    305 SE 2nd Ave   Gainesville             Florida 32601
# ...                             ...           ...                       ...
# 2902  13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                  1125 E 8th St          York       Nebraska 68467-2699
# 2904                Country Club Rd          York   Pennsylvania 17403-3651
# 2905           One University Plaza    Youngstown           Ohio 44555-0001
# 2906          320 South Main Street     Haverhill       Massachusetts 01835
#
#                           3     4     5
# ...

# %%
address1 = universities['address']
address1 = address1.str.strip()
address1 = address1.str.split(',', expand=True) #expand puts results into two separate columns
address2 = address1.rename(columns={0:'street', 1:'city', 2:'state zipcode'})
address2
# Out:
#                              street          city             state zipcode  \
# 0                   800 W Jefferson    Kirksville            Missouri 63501
# 1                 1600 Campus Court       Abilene               Texas 79699
# 2                    2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3               1101 E. 78th Street     Suite 100               Minneapolis
# 4                    305 SE 2nd Ave   Gainesville             Florida 32601
# ...                             ...           ...                       ...
# 2902  13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                  1125 E 8th St          York       Nebraska 68467-2699
# 2904                Country Club Rd          York   Pennsylvania 17403-3651
# 2905           One University Plaza    Youngstown           Ohio 44555-0001
# 2906          320 South Main Street     Haverhill       Massachusetts 01835
#
#                           3     4     5
# ...

# %%
address3 = address2['state zipcode'].str.rsplit(' ',1, expand=True)
address3 = address3.rename(columns={0:'state', 1: 'zip'})
address3
# Out:
#                state          zip
# 0           Missouri        63501
# 1              Texas        79699
# 2            Georgia   31793-2601
# 3                     Minneapolis
# 4            Florida        32601
# ...              ...          ...
# 2902      California        90066
# 2903        Nebraska   68467-2699
# 2904    Pennsylvania   17403-3651
# 2905            Ohio   44555-0001
# 2906   Massachusetts        01835
#
# [2907 rows x 2 columns]

# %%
data1 = pd.concat([universities,address2,address3], axis=1)
data1
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
data1 = data1.drop(columns = ['address','state zipcode', 3, 4, 5])
data1
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                      Website  \
# 0               WWW.ATSU.EDU
# 1                www.acu.edu
# 2               www.abac.edu
# 3     www.academycollege.edu
# 4      www.acupuncturist.edu
# ...                      ...
# 2902           www.yosan.edu
# 2903           www.york.edu/
# ...

# %%
data1['Type'].str.count('4-year').value_counts()
# Out:
# 1    2907
# Name: Type, dtype: int64

# %%
data2 = data1['Type']
data2 = data2.str.strip()
data2 = data2.str.split(',', expand=True) #expand puts results into two separate columns
data2
# Out:
#            0                        1                    2
# 0     4-year   Private not-for-profit                 None
# 1     4-year   Private not-for-profit                 None
# 2     4-year    primarily associate's               Public
# 3     4-year    primarily associate's   Private for-profit
# 4     4-year   Private not-for-profit                 None
# ...      ...                      ...                  ...
# 2902  4-year   Private not-for-profit                 None
# 2903  4-year   Private not-for-profit                 None
# 2904  4-year   Private not-for-profit                 None
# 2905  4-year                   Public                 None
# 2906  4-year   Private not-for-profit                 None
#
# [2907 rows x 3 columns]

# %%
data2 = data1['Type']
data2 = data2.str.strip()
data2 = data2.str.split(',', expand=True) #expand puts results into two separate columns
data2 = data2.rename(columns={0:'years', 1: 'profit/non-profit', 2: 'god knows'})
data2 = data2.drop(columns = ['years'])
data2
# Out:
#             profit/non-profit            god knows
# 0      Private not-for-profit                 None
# 1      Private not-for-profit                 None
# 2       primarily associate's               Public
# 3       primarily associate's   Private for-profit
# 4      Private not-for-profit                 None
# ...                       ...                  ...
# 2902   Private not-for-profit                 None
# 2903   Private not-for-profit                 None
# 2904   Private not-for-profit                 None
# 2905                   Public                 None
# 2906   Private not-for-profit                 None
#
# [2907 rows x 2 columns]

# %%
data2 = data1['Type']
data2 = data2.str.strip()
data2 = data2.str.split(',', expand=True) #expand puts results into two separate columns
data2 = data2.rename(columns={0:'years', 1: 'profit/non-profit', 2: 'god knows'})
data2 = data2.drop(columns = ['years'])
data2.loc[data2['profit/non-profit'] == "primarily associate's", "Primarily Associate's"] = '1'
data2.loc[data2['profit/non-profit'] != "primarily associate's", "Primarily Associate's"] = '0'
data2
# Out:
#             profit/non-profit            god knows Primarily Associate's
# 0      Private not-for-profit                 None                     0
# 1      Private not-for-profit                 None                     0
# 2       primarily associate's               Public                     0
# 3       primarily associate's   Private for-profit                     0
# 4      Private not-for-profit                 None                     0
# ...                       ...                  ...                   ...
# 2902   Private not-for-profit                 None                     0
# 2903   Private not-for-profit                 None                     0
# 2904   Private not-for-profit                 None                     0
# 2905                   Public                 None                     0
# 2906   Private not-for-profit                 None                     0
#
# [2907 rows x 3 columns]
